# %% [markdown]
# https://pyspedas.readthedocs.io/en/latest/ace.html

# %%
import pyspedas
from pytplot import get_data,tplot

# %%
mag_data = get_data('mms1_fgm_b_gse_srvy_l2_bvec')

# get_data returns a namedtuple with 'times' and 'y':
mag_data.times # the unix times, stored as a numpy array
mag_data.y # the data values

# %%
mfi_vars = pyspedas.ace.mfi(trange=['2018-11-5', '2018-11-6'])
tplot(['BGSEc', 'Magnitude'])
# Out:
# 01-Mar-24 03:57:44: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/ace/mag/level_2_cdaweb/mfi_h3/2018/
# 01-Mar-24 03:57:45: Downloading https://spdf.gsfc.nasa.gov/pub/data/ace/mag/level_2_cdaweb/mfi_h3/2018/ac_h3_mfi_20181105_v03.cdf to ace_data/mag/level_2_cdaweb/mfi_h3/2018/ac_h3_mfi_20181105_v03.cdf
# 01-Mar-24 03:57:45: Download complete: ace_data/mag/level_2_cdaweb/mfi_h3/2018/ac_h3_mfi_20181105_v03.cdf
